# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 5 Invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.

# %% [markdown]
# | Groep: 5     |  |
# | :-------------|:-------------|
# | Jelle Kooloos | 6532241 |
# | George de Jong| 6468845 |
# | Robert den Haan | 6512186 |

# %% [markdown]
# ## Opdracht 1: Planning.

# %% [markdown]
# | Planning Groep: 05     |Tijdstip / Tijdspanne  | door wie  |
# |---|---|---|
# | Arduino testen| 10:45 - 12:30 | Robert |
# | ontwerp-eis berekenen| 10:45 - 12:30 | Jelle & George|
# | Beslissen delta x en laten zien sanity check | 12:30-12:45 | hele groep |
# | Synthese+simulatie | 13:45-14:30 | hele groep |
# | Meetplan+Fabricage| 14:30-15:15 | hele groep |
# | Metingen doen| 15:30-15:45| hele groep |
# | Iteratie 1 | 15:45-16:30|
# | Verbeteringen| 16:30-17:00|
# | Opruimen|17:00-17:30|
# | Mijlpaal 1 | Tijdstip | ---|
# | Mijlpaal 2 | Tijdstip | ---|
# | Pauze 1| 12:35 - 13:25 | hele groep |

# %% [markdown]
# Run onderstaande cel om alle benodigde libraries te laden. Mogelijk voeg je er zelf nog een aantal toe later vandaag.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time
import math

# %% [markdown]
# ## Opdracht 2a: Opsplitsen taak 1: Arduino
# Vul onderstaande tabel in:

# %% [markdown]
# | onderwerp    | antwoord  |
# |---|---|
# | hoe moeilijk (schaal 1 - 10) | 5 |
# | hoe lang voor één meting | 2min |
# | verwacht nauwkeurigheid meting | 5% |

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %%
# Bereken hier je benodigde kantelfrequentie
#f=3.54 #Hz
f=2.5

# %%
# Voeg hier je plot in.
w = np.linspace(0,100,1000)
w_0=f*2*np.pi
def func(x):
    return 1/(1-(x**2/w_0**2))

plt.loglog(w,np.abs(func(w,)),label="w")
plt.ylim(0,30)
plt.xlim(0,100)
plt.title('Amplitude overdracht')
plt.xlabel("log(w)")
plt.ylabel("log(A_m/A_v)")
plt.axvline(x=w_0,color="red",label="w_0")
plt.legend()
plt.show
# Out:
# C:\Users\Jelle\AppData\Local\Temp\ipykernel_21836\4193008765.py:8: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0,30)
# C:\Users\Jelle\AppData\Local\Temp\ipykernel_21836\4193008765.py:9: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0,100)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### Afleiding Delta x:
# <img src="image1x.png" width="400">

# %%
# Bereken hier de minimale Delta-x waarbij je aan de eis van de opdracht voldoet.
g=9.81
delta_x=g/(w_0**2)
print(delta_x)
# Out:
# 0.039758432461253344

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
# Voeg hier je plot in. Lees goed de opdracht wat er in de grafiek moet staan!
# Het is ook handig om je grafiek op te slaan, doe dat door met plt.savefig().
#Veerconstante=np.linspace(0,10,1000)
massa=np.linspace(0,3,1000)

delta_x_1=delta_x*2
delta_x_doen= delta_x*2.5
delta_x_2=delta_x*5

def funct_C_m(C):
    return delta_x*C/g

def func1(m,delta_x):
    return 9.81*m/delta_x


#plt.(func_C_m(Veerconstante),Veerconstante)
plt.figure()
plt.plot(massa,func1(massa,delta_x),label="Delta")
plt.plot(massa,func1(massa,delta_x_1),label="2*Delta")
plt.plot(massa,func1(massa,delta_x_2),label="5*Delta")
plt.plot(massa,func1(massa,delta_x_doen),label="2.5*Delta")
plt.ylabel("Veerconstante (N/m)")
plt.xlabel("Massa (kg)")
plt.legend()
plt.show()
plt.savefig("Veerconstante_massa.png")

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - De massa te verhogen
# - De veerconstante te verkleinen
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van: 0.10

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
# <img src="Foto_extra.png" width="400">

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# **0.10m**
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# **.**
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# **Tussen de 20 en 50 cm is de veer lineair**
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# **Ja**
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# **Ja**
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
# Voeg hier je plot in.
delta_x_gemeten=0.35
w_0_gemeten=np.sqrt(g/delta_x_gemeten)
def func_gemeten(x):
    return 1/(1-((x**2)/(w_0_gemeten**2)))


plt.loglog(w,np.abs(func_gemeten(w)),label="w_ontwerp.0")
plt.loglog(w,np.abs(func(w)),label="w_min")
plt.ylim(0,30)
plt.xlim(0,100)
plt.title('Amplitude overdracht')
plt.xlabel("log(w)")
plt.ylabel("log(A_m/A_v)")
plt.axvline(x=w_0_gemeten,color="red",label="w_0_ontwerp.0")
plt.axvline(x=w_0,color="green",label="w_0_min")
plt.legend()
plt.show
# Out:
# C:\Users\Jelle\AppData\Local\Temp\ipykernel_21836\14002146.py:10: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0,30)
# C:\Users\Jelle\AppData\Local\Temp\ipykernel_21836\14002146.py:11: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0,100)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# De opstelling:
# <img src="image1.png" width="400">
#
#
# Voldeed aan de eisen, deze iteratie had aan elke zijde een ketting van 6 elastiekjes. De vraag was of bij een kortere kettingen werd er verwacht dat er een meer linear verband was. Dus dit is geprobeerd.

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# **2.5**
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# Ja de $\Delta x$ behaald met de gekozen massa en veer is **0.35m**
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# **Tussen de 10 en 30 cm is de veer lineair**
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# **Ja**
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# **Ja**
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
delta_x_gemeten_2=0.15
w_0_gemeten_2=np.sqrt(g/delta_x_gemeten_2)
def func_gemeten_2(x):
    return 1/(1-((x**2)/(w_0_gemeten_2**2)))


plt.loglog(w,np.abs(func_gemeten_2(w)),label="w_ontwerp.1")
plt.loglog(w,np.abs(func(w)),label="w_min")
plt.ylim(0,30)
plt.xlim(0,100)
plt.title('Amplitude overdracht')
plt.xlabel("log(w)")
plt.ylabel("log(A_m/A_v)")
plt.axvline(x=w_0_gemeten_2,color="red",label="w_0_ontwerp.1")
plt.axvline(x=w_0,color="green",label="w_0_min")
plt.legend()
plt.show
# Out:
# C:\Users\Jelle\AppData\Local\Temp\ipykernel_21836\2529897223.py:9: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0,30)
# C:\Users\Jelle\AppData\Local\Temp\ipykernel_21836\2529897223.py:10: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0,100)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <img src="image2.png" width="400">

# %% [markdown]
# Voldeed aan de eisen, deze iteratie had aan elke zijde een ketting van 2 elastiekjes. Dit werkte beter en is dus gebruikt om de uiteindelijke opstelling te bouwen.

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
#Metingen
A_V=np.array([2.4,6.2,6.3,4.9])
A_m=np.array([0.64,1.9,0.8,0.9])
A_mA_V=A_m/A_V
Frequentie=np.array([3,4.8,7.7,5.9])
w_echt=Frequentie*2*np.pi
#onzekerheid
Onz_A_v=np.array([0.1,0.3,0.3,0.3])
Onz_A_m=np.array([0.1,0.15,0.15,0.2])
onz_A_mA_V=np.sqrt((Onz_A_v**2)+(Onz_A_m**2))
Onz_Freq=np.array([0.1,0.1,0.2,0.1])


plt.loglog(w,np.abs(func_gemeten_2(w)),label="w_ontwerp.1")
plt.loglog(w,np.abs(func(w)),label="w_min")
plt.errorbar(w_echt,A_mA_V, xerr=Onz_Freq,yerr=onz_A_mA_V,fmt="none",label="Metingen met error")
plt.scatter(w_echt,A_mA_V)
#Metingen plotten

plt.ylim(0.05,10)
plt.xlim(0,400)
plt.title('Amplitude overdracht')
plt.xlabel("log(w)")
plt.ylabel("log(A_m/A_v)")
plt.axvline(x=w_0_gemeten_2,color="red",label="w_0_ontwerp.1")
plt.axvline(x=w_0,color="green",label="w_0_min")
plt.legend()
plt.show
# Out:
# C:\Users\Jelle\AppData\Local\Temp\ipykernel_21836\2806764346.py:21: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0,400)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Metingen
A_V_2=np.array([2.94,4.55,4.84,4.34])
A_m_2=np.array([0.69,0.73,0.64,0.82])
A_mA_V_2=A_m_2/A_V_2
Frequentie_2=np.array([3.2,4.5,6.5,5.1])
w_echt_2=Frequentie_2*2*np.pi
#onzekerheid
Onz_A_v_2=np.array([0.08,0.06,0.04,0.08])
Onz_A_m_2=np.array([0.06,0.07,0.07,0.08])
onz_A_mA_V_2=np.sqrt((Onz_A_v_2**2)+(Onz_A_m_2**2))
Onz_Freq_2=np.array([0.05,0.05,0.05,0.04])

plt.loglog(w,np.abs(func_gemeten_2(w)),label="w_ontwerp.2")
plt.loglog(w,np.abs(func(w)),label="w_min")
plt.errorbar(w_echt_2,A_mA_V_2, xerr=Onz_Freq_2,yerr=onz_A_mA_V_2,fmt="none",label="Metingen met error")
plt.scatter(w_echt_2,A_mA_V_2)
#Metingen plotten

plt.ylim(0.05,10)
plt.xlim(0,400)
plt.title('Amplitude overdracht')
plt.xlabel("log(w)")
plt.ylabel("log(A_m/A_v)")
plt.axvline(x=w_0_gemeten_2,color="red",label="w_0_ontwerp.2")
plt.axvline(x=w_0,color="green",label="w_0_min")
plt.legend()
plt.show
# Out:
# C:\Users\Jelle\AppData\Local\Temp\ipykernel_21836\555256372.py:20: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0,400)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# De verkregen metingen lopen toch nog zeer ver uiteen.
# Potentiële redenen hiervoor zijn:
# 1. Water klotst:
# Het water in de beker, dat het gewicht onderaan de veer vormt, klost heen en weer. Dit interfereert met de trillingen.
#
# 2. Elastieke vervormen:
# De elastieken hebben zijn langere tijd uitgerekt. Hierdoor zijn ze, tussen metingen in, vervormd.
#
# 3. De sate-prikkes buigen mee:
# De sate-prikkers buigen mee, als veer. Deze veer werkt niet volgens de wet van Hook.
#
# 4. De elastieken werken niet lineair.
# De elastiekjes veren niet mee zoals beschreven in de wet van Hook. Het model klopt daarom niet met de werkelijkheid.

# %% [markdown]
# ## Opdracht 8: Leerdoelen
# Voeg hieronder zelf kopjes toe om aan te geven wat bij welk leerdoel hoort.

# %% [markdown]
# ## Leerdoel 1:
#
# **Inzien dat de parameters in een differtiaalvergelijking ontwerpparameters zijn die een ontwerpruimte opspannen**

# %% [markdown]
# #### Als je je figuren onderweg opgeslagen hebt, kan je ze hier invoegen:
# <img src="output.png" width="400">

# %% [markdown]
# ##### Afleiding Delta x:
# <img src="image1x.png" width="400">

# %%
#Metingen
A_V_2=np.array([2.94,4.55,4.84,4.34])
A_m_2=np.array([0.69,0.73,0.64,0.82])
A_mA_V_2=A_m_2/A_V_2
Frequentie_2=np.array([3.2,4.5,6.5,5.1])
w_echt_2=Frequentie_2*2*np.pi
#onzekerheid
Onz_A_v_2=np.array([0.08,0.06,0.04,0.08])
Onz_A_m_2=np.array([0.06,0.07,0.07,0.08])
onz_A_mA_V_2=np.sqrt((Onz_A_v_2**2)+(Onz_A_m_2**2))
Onz_Freq_2=np.array([0.05,0.05,0.05,0.04])

plt.loglog(w,np.abs(func_gemeten_2(w)),label="w_ontwerp.2")
plt.loglog(w,np.abs(func(w)),label="w_min")
plt.errorbar(w_echt_2,A_mA_V_2, xerr=Onz_Freq_2,yerr=onz_A_mA_V_2,fmt="none",label="Metingen met error")
plt.scatter(w_echt_2,A_mA_V_2)
#Metingen plotten

plt.ylim(0.05,10)
plt.xlim(0,400)
plt.title('Amplitude overdracht')
plt.xlabel("log(w)")
plt.ylabel("log(A_m/A_v)")
plt.axvline(x=w_0_gemeten_2,color="red",label="w_0_ontwerp.2")
plt.axvline(x=w_0,color="green",label="w_0_min")
plt.legend()
plt.show
# Out:
# C:\Users\Jelle\AppData\Local\Temp\ipykernel_21836\555256372.py:20: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0,400)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Leerdoel 2:
# **Op basis van een differentiaalvergelijking een keuze maken voor parameters en die vervolgens kunnen vertalen in een fysiek ontwerp**

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - De massa te verhogen
# - De veerconstante te verkleinen
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van: 0.10

# %% [markdown]
# #### Als je je figuren onderweg opgeslagen hebt, kan je ze hier invoegen:
# <img src="Foto_extra.png" width="400">
# <img src="image2.png" width="400">

# %%
#Metingen
A_V_2=np.array([2.94,4.55,4.84,4.34])
A_m_2=np.array([0.69,0.73,0.64,0.82])
A_mA_V_2=A_m_2/A_V_2
Frequentie_2=np.array([3.2,4.5,6.5,5.1])
w_echt_2=Frequentie_2*2*np.pi
#onzekerheid
Onz_A_v_2=np.array([0.08,0.06,0.04,0.08])
Onz_A_m_2=np.array([0.06,0.07,0.07,0.08])
onz_A_mA_V_2=np.sqrt((Onz_A_v_2**2)+(Onz_A_m_2**2))
Onz_Freq_2=np.array([0.05,0.05,0.05,0.04])

plt.loglog(w,np.abs(func_gemeten_2(w)),label="w_ontwerp.2")
plt.loglog(w,np.abs(func(w)),label="w_min")
plt.errorbar(w_echt_2,A_mA_V_2, xerr=Onz_Freq_2,yerr=onz_A_mA_V_2,fmt="none",label="Metingen met error")
plt.scatter(w_echt_2,A_mA_V_2)
#Metingen plotten

plt.ylim(0.05,10)
plt.xlim(0,400)
plt.title('Amplitude overdracht')
plt.xlabel("log(w)")
plt.ylabel("log(A_m/A_v)")
plt.axvline(x=w_0_gemeten_2,color="red",label="w_0_ontwerp.2")
plt.axvline(x=w_0,color="green",label="w_0_min")
plt.legend()
plt.show
# Out:
# C:\Users\Jelle\AppData\Local\Temp\ipykernel_21836\555256372.py:20: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0,400)
# <function matplotlib.pyplot.show(close=None, block=None)>
